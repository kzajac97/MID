# %% [markdown]
# # Template Notebook

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Standard library imports

# %%
# %load_ext autoreload

# %%
import sys
import warnings
import logging

sys.path.append('..')
warnings.filterwarnings('ignore')
logger = logging.getLogger(__name__)

# %% [markdown]
# ### Standard library imports

# %% [markdown]
# ### Thrid Party libraries imports

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# ### Modules imports

# %%
# %autoreload 2

from source.functions.distributions import cauchy, exponential, laplace, logistic, triangle
from source.functions.cumulative import cumulative_cauchy, cumulative_exponential, cumulative_laplace, cumulative_logistic, cumulative_triangle
from source.functions.inverse import inverse_triangle
from source.generators.inverted_distribution import cdf, _sample_analytic_distribution

# %% [markdown]
# ### Paths

# %%
triangle_dist = _sample_analytic_distribution(1000, 'triangle', sample_range=(0.0, 1.0))

# %%
figure = plt.figure(figsize=[20, 8])

plt.hist(triangle_dist, bins=20)

plt.grid()
